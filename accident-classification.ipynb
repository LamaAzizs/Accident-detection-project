# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from time import perf_counter 
import os
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.utils import plot_model
# Out:
# 2024-10-11 20:19:59.381198: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-11 20:19:59.381277: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-11 20:19:59.383060: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-11 20:19:59.520154: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Defining batch specfications
batch_size = 16
img_height = 224
img_width = 224

# %%
print(tf.__version__)
# Out:
# 2.14.0

# %%
## loading training set
training_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/train',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 791 files belonging to 2 classes.
# 2024-10-11 20:20:08.001463: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.026987: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.027048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.028954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.029000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.029024: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.303494: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.303550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.303557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-10-11 20:20:08.303592: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-10-11 20:20:08.303609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
## loading validation dataset
validation_data =  tf.keras.preprocessing.image_dataset_from_directory(
    'data/val',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 98 files belonging to 2 classes.

# %%
## loading testing dataset
testing_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/test',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 100 files belonging to 2 classes.

# %%
testing_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 250, 250, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = training_data.class_names
class_names
# Out:
# ['Accident', 'Non Accident']

# %%
## Configuring dataset for performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_data = training_data.cache().prefetch(buffer_size=AUTOTUNE)
testing_data = testing_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
## Defining Cnn
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'), # Conv2D(f_size, filter_size, activation) # relu, sigmoid, softmax
  layers.MaxPooling2D(), # MaxPooling
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(len(class_names), activation= 'softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.build((None, 224, 224, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 224, 224, 3)       12
#  Normalization)
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 224, 224, 3)       12
#  Normalization)
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 19264334 (73.49 MB)
# Trainable params: 19264328 (73.49 MB)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
## lets train our CNN
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(training_data, validation_data=validation_data, epochs = 20, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 2024-10-11 20:20:51.087507: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2024-10-11 20:20:52.202469: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fbfc00170a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-11 20:20:52.202502: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-10-11 20:20:52.209995: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-11 20:20:52.305377: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50/50 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.5954
# Epoch 1: val_accuracy improved from -inf to 0.70408, saving model to model_weights.h5
# /home/talib/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 50/50 [==============================] - 8s 80ms/step - loss: 1.1266 - accuracy: 0.5954 - val_loss: 0.6381 - val_accuracy: 0.7041
# Epoch 2/20
# Epoch 2/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.5849 - accuracy: 0.7054
# Epoch 2: val_accuracy improved from 0.70408 to 0.77551, saving model to model_weights.h5
# 50/50 [==============================] - 2s 46ms/step - loss: 0.5829 - accuracy: 0.7080 - val_loss: 0.4811 - val_accuracy: 0.7755
# Epoch 3/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.4543 - accuracy: 0.7768
# Epoch 3: val_accuracy improved from 0.77551 to 0.84694, saving model to model_weights.h5
# 50/50 [==============================] - 2s 48ms/step - loss: 0.4517 - accuracy: 0.7788 - val_loss: 0.3715 - val_accuracy: 0.8469
# Epoch 4/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.3091 - accuracy: 0.8648
# Epoch 4: val_accuracy did not improve from 0.84694
# 50/50 [==============================] - 2s 32ms/step - loss: 0.3064 - accuracy: 0.8660 - val_loss: 0.6023 - val_accuracy: 0.7959
# Epoch 5/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.2441 - accuracy: 0.9069
# Epoch 5: val_accuracy improved from 0.84694 to 0.86735, saving model to model_weights.h5
# 50/50 [==============================] - 2s 39ms/step - loss: 0.2420 - accuracy: 0.9077 - val_loss: 0.4683 - val_accuracy: 0.8673
# Epoch 6/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.1800 - accuracy: 0.9286
# Epoch 6: val_accuracy improved from 0.86735 to 0.91837, saving model to model_weights.h5
# 50/50 [==============================] - 2s 40ms/step - loss: 0.1784 - accuracy: 0.9292 - val_loss: 0.2775 - val_accuracy: 0.9184
# Epoch 7/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9452
# Epoch 7: val_accuracy did not improve from 0.91837
# 50/50 [==============================] - 2s 30ms/step - loss: 0.1578 - accuracy: 0.9456 - val_loss: 0.2870 - val_accuracy: 0.9082
# Epoch 8/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9515
# Epoch 8: val_accuracy did not improve from 0.91837
# 50/50 [==============================] - 2s 30ms/step - loss: 0.1268 - accuracy: 0.9520 - val_loss: 0.2925 - val_accuracy: 0.8980
# Epoch 9/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9528
# Epoch 9: val_accuracy improved from 0.91837 to 0.93878, saving model to model_weights.h5
# 50/50 [==============================] - 2s 44ms/step - loss: 0.1116 - accuracy: 0.9532 - val_loss: 0.2456 - val_accuracy: 0.9388
# Epoch 10/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0972 - accuracy: 0.9745
# Epoch 10: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 30ms/step - loss: 0.0963 - accuracy: 0.9747 - val_loss: 0.2390 - val_accuracy: 0.9286
# Epoch 11/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9668
# Epoch 11: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.1012 - accuracy: 0.9671 - val_loss: 0.2394 - val_accuracy: 0.9184
# Epoch 12/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9821
# Epoch 12: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0528 - accuracy: 0.9823 - val_loss: 0.2595 - val_accuracy: 0.9184
# Epoch 13/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0679 - accuracy: 0.9809
# Epoch 13: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0673 - accuracy: 0.9810 - val_loss: 0.2671 - val_accuracy: 0.8980
# Epoch 14/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0463 - accuracy: 0.9847
# Epoch 14: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0459 - accuracy: 0.9848 - val_loss: 0.1792 - val_accuracy: 0.9388
# Epoch 15/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9847
# Epoch 15: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0434 - accuracy: 0.9848 - val_loss: 0.2149 - val_accuracy: 0.9388
# Epoch 16/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0428 - accuracy: 0.9834
# Epoch 16: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 32ms/step - loss: 0.0424 - accuracy: 0.9836 - val_loss: 0.2553 - val_accuracy: 0.9082
# Epoch 17/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9860
# Epoch 17: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0414 - accuracy: 0.9861 - val_loss: 0.3078 - val_accuracy: 0.9082
# Epoch 18/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9885
# Epoch 18: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0339 - accuracy: 0.9886 - val_loss: 0.2879 - val_accuracy: 0.8980
# Epoch 19/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0189 - accuracy: 0.9936
# Epoch 19: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.1570 - val_accuracy: 0.9286
# Epoch 20/20
# 49/50 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9923
# Epoch 20: val_accuracy did not improve from 0.93878
# 50/50 [==============================] - 2s 31ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 0.2021 - val_accuracy: 0.9286

# %%
###### serialize model structure to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
## stats on training data
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.grid(True)
plt.legend()

# %%
## stats on training data
plt.plot(history.history['val_loss'], label = 'validation loss')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.grid(True)
plt.legend()

# %%
## lets vizualize results on testing data
AccuracyVector = []
plt.figure(figsize=(30, 30))
for images, labels in testing_data.take(1):
    predictions = model.predict(images)
    predlabel = []
    prdlbl = []
    
    for mem in predictions:
        predlabel.append(class_names[np.argmax(mem)])
        prdlbl.append(np.argmax(mem))
    
    AccuracyVector = np.array(prdlbl) == labels
    for i in range(16):
        ax = plt.subplot(10, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title('Pred: '+ predlabel[i]+' actl:'+class_names[labels[i]] )
        plt.axis('off')
        plt.grid(True)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 2024-10-11 20:23:28.930843: W tensorflow/core/kernels/data/cache_dataset_ops.cc:854] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
predictions

# %%
model.save('models/my_model')
# Out:
# INFO:tensorflow:Assets written to: models/my_model/assets
# INFO:tensorflow:Assets written to: models/my_model/assets
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
